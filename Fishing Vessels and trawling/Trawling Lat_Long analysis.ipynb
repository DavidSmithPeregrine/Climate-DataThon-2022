# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('c:\\Users\\Pablo\\Documents\\Climate DataThon 2022\\Climate-DataThon-2022\\Fishing Vessels and Trawling')

# %% [markdown]
# https://globalfishingwatch.org/data-download/datasets/public-training-data-v1

# %%
fishing_data = pd.read_csv('Data/fishing-vessels-v2.csv')
fishing_data
# Out:
#              mmsi flag_ais flag_registry flag_gfw vessel_class_inferred  \
# 0        40120000      NaN           GRC      GRC                   NaN
# 1       444002410      NaN           KOR      KOR                   NaN
# 2       987654320      NaN           PHL      PHL                   NaN
# 3       554128120      NaN           NRU      NRU                   NaN
# 4       112119600      NaN           USA      USA                   NaN
# ...           ...      ...           ...      ...                   ...
# 114186  601523000      ZAF           NaN      ZAF    other_purse_seines
# 114187  601554000      ZAF           NaN      ZAF    other_purse_seines
# 114188  601556000      ZAF           NaN      ZAF    other_purse_seines
# 114189  601039500      ZAF           NaN      ZAF    other_purse_seines
# 114190  601557000      ZAF           ZAF      ZAF    other_purse_seines
#
#         vessel_class_inferred_score vessel_class_registry    vessel_class_gfw  \
# ...

# %%
fishing_data.columns = ['mmsi', 'flag_ais', 'flag_registry', 'flag_gfw',
       'vessel_class_inferred', 'vessel_class_inferred_score',
       'vessel_class_registry', 'vessel_class_gfw',
       'self_reported_fishing_vessel', 'length_m_inferred',
       'length_m_registry', 'length_m_gfw', 'engine_power_kw_inferred',
       'engine_power_kw_registry', 'engine_power_kw_gfw',
       'tonnage_gt_inferred', 'tonnage_gt_registry', 'tonnage_gt_gfw',
       'registries_listed', 2012, 2013,
       2014, 2015, 2016,
       2017, 2018, 2019,
       2020]

# %%
fishing_data_melt = fishing_data.melt(id_vars=['mmsi', 'flag_ais', 'flag_registry', 'flag_gfw',
       'vessel_class_inferred', 'vessel_class_inferred_score',
       'vessel_class_registry', 'vessel_class_gfw',
       'self_reported_fishing_vessel', 'length_m_inferred',
       'length_m_registry', 'length_m_gfw', 'engine_power_kw_inferred',
       'engine_power_kw_registry', 'engine_power_kw_gfw',
       'tonnage_gt_inferred', 'tonnage_gt_registry', 'tonnage_gt_gfw', 'registries_listed'], 
        var_name="Date", 
        value_name="Hours")

# %%
fishing_data_melt
# Out:
#               mmsi flag_ais flag_registry flag_gfw vessel_class_inferred  \
# 0         40120000      NaN           GRC      GRC                   NaN
# 1        444002410      NaN           KOR      KOR                   NaN
# 2        987654320      NaN           PHL      PHL                   NaN
# 3        554128120      NaN           NRU      NRU                   NaN
# 4        112119600      NaN           USA      USA                   NaN
# ...            ...      ...           ...      ...                   ...
# 1027714  601523000      ZAF           NaN      ZAF    other_purse_seines
# 1027715  601554000      ZAF           NaN      ZAF    other_purse_seines
# 1027716  601556000      ZAF           NaN      ZAF    other_purse_seines
# 1027717  601039500      ZAF           NaN      ZAF    other_purse_seines
# 1027718  601557000      ZAF           ZAF      ZAF    other_purse_seines
#
#          vessel_class_inferred_score vessel_class_registry  \
# ...

# %%
trawling_data = fishing_data_melt[fishing_data_melt['vessel_class_gfw'] == 'trawlers']
trawling_data_grouped = trawling_data.groupby(['flag_gfw','Date']).sum().reset_index()
trawling_data_grouped[trawling_data_grouped['flag_gfw'] =='USA']
# Out:
#     flag_gfw  Date          mmsi  vessel_class_inferred_score  \
# 981      USA  2012  517632501619                     1176.099
# 982      USA  2013  517632501619                     1176.099
# 983      USA  2014  517632501619                     1176.099
# 984      USA  2015  517632501619                     1176.099
# 985      USA  2016  517632501619                     1176.099
# 986      USA  2017  517632501619                     1176.099
# 987      USA  2018  517632501619                     1176.099
# 988      USA  2019  517632501619                     1176.099
# 989      USA  2020  517632501619                     1176.099
#
#      length_m_inferred  length_m_registry  length_m_gfw  \
# 981           35667.73           23339.22      36010.39
# 982           35667.73           23339.22      36010.39
# 983           35667.73           23339.22      36010.39
# 984           35667.73           23339.22      36010.39
# 985           35667.73           23339.22      36010.39
# ...

# %%
os.chdir('c:\\Users\\Pablo\\Documents\\Climate DataThon 2022\\Climate-DataThon-2022\\Fishing Vessels and Trawling')
fishing_data = pd.read_csv('Data/fishing-vessels-v2.csv')
fishing_data.columns = ['mmsi', 'flag_ais', 'flag_registry', 'flag_gfw',
       'vessel_class_inferred', 'vessel_class_inferred_score',
       'vessel_class_registry', 'vessel_class_gfw',
       'self_reported_fishing_vessel', 'length_m_inferred',
       'length_m_registry', 'length_m_gfw', 'engine_power_kw_inferred',
       'engine_power_kw_registry', 'engine_power_kw_gfw',
       'tonnage_gt_inferred', 'tonnage_gt_registry', 'tonnage_gt_gfw',
       'registries_listed', 2012, 2013,
       2014, 2015, 2016,
       2017, 2018, 2019,
       2020]
fishing_data_melt = fishing_data.melt(id_vars=['mmsi', 'flag_ais', 'flag_registry', 'flag_gfw',
       'vessel_class_inferred', 'vessel_class_inferred_score',
       'vessel_class_registry', 'vessel_class_gfw',
       'self_reported_fishing_vessel', 'length_m_inferred',
       'length_m_registry', 'length_m_gfw', 'engine_power_kw_inferred',
       'engine_power_kw_registry', 'engine_power_kw_gfw',
       'tonnage_gt_inferred', 'tonnage_gt_registry', 'tonnage_gt_gfw', 'registries_listed'], 
        var_name="Date", 
        value_name="Hours")
trawling_data = fishing_data_melt[fishing_data_melt['vessel_class_gfw'] == 'trawlers']
trawling_data_grouped = trawling_data.groupby(['flag_gfw','Date']).sum().reset_index()
trawling_data_grouped = trawling_data_grouped[['flag_gfw', 'Date', 'Hours']]
# Out:
#      flag_gfw  Date         mmsi  vessel_class_inferred_score  \
# 0         ABW  2012    307005349                        0.910
# 1         ABW  2013    307005349                        0.910
# 2         ABW  2014    307005349                        0.910
# 3         ABW  2015    307005349                        0.910
# 4         ABW  2016    307005349                        0.910
# ...       ...   ...          ...                          ...
# 1048      ZAF  2016  43299146600                       67.278
# 1049      ZAF  2017  43299146600                       67.278
# 1050      ZAF  2018  43299146600                       67.278
# 1051      ZAF  2019  43299146600                       67.278
# 1052      ZAF  2020  43299146600                       67.278
#
#       length_m_inferred  length_m_registry  length_m_gfw  \
# 0                 17.01                0.0         17.01
# 1                 17.01                0.0         17.01
# ...

# %% [markdown]
# # Using API

# %%
import requests

# %%
api_key = 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6ImtpZEtleSJ9.eyJkYXRhIjp7Im5hbWUiOiJDT1BfRGF0YVRob24iLCJ1c2VySWQiOjIwOTQxLCJhcHBsaWNhdGlvbk5hbWUiOiJDT1BfRGF0YVRob24iLCJpZCI6MjQxLCJ0eXBlIjoidXNlci1hcHBsaWNhdGlvbiJ9LCJpYXQiOjE2NjQ5Nzc0MjIsImV4cCI6MTk4MDMzNzQyMiwiYXVkIjoiZ2Z3IiwiaXNzIjoiZ2Z3In0.TGc9n9SfJ3fmWNVHJPloQjWdVp-PHqEWoGfrV1-IzyXn0BVGJ0OdU4y5s0VvTc3sNSeQt6rd_gv1NyDTFxk5iSCF_ah8bDYpHvIEX7gxZJ6TXIpfGNMqgj3Pz6YiZEN0jomtpQqh0wkPERIIKMWtoE7TmmVI-qTTRvYv2CruUuM4nk27zMEhCM180n-s9ZK4M61biBNmfP0L-SJcttCkSA9uHahzpetaaDb2xuponIhEBdFlPdX_zFVnjjTYzZF0d5Q4xTVNp0JNXXRgIGC2qddO3i7aFUlffEHfiUnTG3eYcD_zmZGRo2ixUDwsq5ACfLXpPNtzA286PIEdj-dTEitRPn8vNE2ks3sIZoPnrSYo-6vsQwnF_4zGMsrIePw_eup0raxouQMTz5IDVpcK9ifvnCt3erPaqCjS0MGOzy4zIAEwwxrhCCyAXtSEQzC6tbQ0ZM5vNozcW4tY5oIq6UpBFOoug0Zbb0d2y38RLumoslLyh-tn_IZfEnUA4g0J'

# %%
import requests
from requests.auth import HTTPBasicAuth
auth = HTTPBasicAuth('apikey', api_key)
requests.get('https://gateway.api.globalfishingwatch.org/v2/events', auth = auth).text
# Out:
# '{"error":"Not authorized"}\n'

# %%
url = 'https://gateway.api.globalfishingwatch.org/v2/events'
headers = {'Authorization': f'Bearer {api_key}'}
auth = HTTPBasicAuth('apikey', '1234abcd')
requests.get(url, headers=headers).text
# Out:
# '{"metadata":{"query":"7831410","suggestion":null,"field":"shipname"},"total":1,"limit":1,"offset":0,"nextOffset":1,"entries":[{"callsign":"LW3058","firstTransmissionDate":"2016-12-20T20:27:39Z","flag":"ARG","geartype":"squid_jigger","id":"9b3e9019d-d67f-005a-9593-b66b997559e5","imo":"7831410","lastTransmissionDate":"2022-10-02T23:48:16Z","mmsi":"701000948","msgCount":550932990,"posCount":1896279,"shipname":"CLAUDINA","source":"AIS","vesselType":"Fishing","years":[2016,2017,2018,2019,2020,2021,2022],"dataset":"public-global-fishing-vessels:v20201001","score":87.928665}]}'
