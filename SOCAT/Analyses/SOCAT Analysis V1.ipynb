# %%
import pandas as pd
import os
import seaborn as sns

# %%
os.chdir('c:\\Users\\Pablo\\Documents\\Climate DataThon 2022\\Climate-DataThon-2022')

# %% [markdown]
# ### Read SOCAT Data

# %%
'''******************************************************************************							
**** NOTE: rows containing no data (cruise count is zero) are not printed ****							
******************************************************************************							
							
							
             DATA SET: ./SOCAT_tracks_gridded_monthly.nc							
             SOCAT gridded v2022 Monthly 1x1 degree gridded dataset							
             LONGITUDE: 179.5W(-179.5)							
             LATITUDE: 89.5S							
             TIME: 1970-01-16 12:00							
 Column  1: DATE is ISO Date representing the month midpoint (axis TMNTH)							
 Column  2: LAT is Latitude (axis YLAT)							
 Column  3: LON is Longitude (axis XLON)							
 Column  4: COUNT_NCRUISE is Number of cruises (count)							
 Column  5: FCO2_COUNT_NOBS is Number of fco2 obs (count)							
 Column  6: FCO2_AVE_WEIGHTED is fCO2 mean - per cruise weighted (uatm)							
 Column  7: FCO2_AVE_UNWTD is fCO2 mean - unweighted all obs (uatm)							
 Column  8: FCO2_MIN_UNWTD is fCO2 min (uatm)							
 Column  9: FCO2_MAX_UNWTD is fCO2 max (uatm)							
 Column 10: SST_COUNT_NOBS is Number of valid sst obs (count)							
 Column 11: SST_AVE_WEIGHTED is SST mean - per cruise weighted (degrees C)							
 Column 12: SST_AVE_UNWTD is SST mean - unweighted all obs (degrees C)							
 Column 13: SST_MIN_UNWTD is SST min (degrees C)							
 Column 14: SST_MAX_UNWTD is SST max (degrees C)							
 Column 15: SALINITY_COUNT_NOBS is Number of valid salinity obs (count)							
 Column 16: SALINITY_AVE_WEIGHTED is Salinity mean - per cruise weighted (PSU)							
 Column 17: SALINITY_AVE_UNWTD is Salinity mean - unweighted all obs (PSU)							
 Column 18: SALINITY_MIN_UNWTD is Salinity min (PSU)							
 Column 19: SALINITY_MAX_UNWTD is Salinity max (PSU)							
							
Missing values are represented as -1.E+34							
'''
# Out:
# '******************************************************************************\t\t\t\t\t\t\t\n**** NOTE: rows containing no data (cruise count is zero) are not printed ****\t\t\t\t\t\t\t\n******************************************************************************\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n             DATA SET: ./SOCAT_tracks_gridded_monthly.nc\t\t\t\t\t\t\t\n             SOCAT gridded v2022 Monthly 1x1 degree gridded dataset\t\t\t\t\t\t\t\n             LONGITUDE: 179.5W(-179.5)\t\t\t\t\t\t\t\n             LATITUDE: 89.5S\t\t\t\t\t\t\t\n             TIME: 1970-01-16 12:00\t\t\t\t\t\t\t\n Column  1: DATE is ISO Date representing the month midpoint (axis TMNTH)\t\t\t\t\t\t\t\n Column  2: LAT is Latitude (axis YLAT)\t\t\t\t\t\t\t\n Column  3: LON is Longitude (axis XLON)\t\t\t\t\t\t\t\n Column  4: COUNT_NCRUISE is Number of cruises (count)\t\t\t\t\t\t\t\n Column  5: FCO2_COUNT_NOBS is Number of fco2 obs (count)\t\t\t\t\t\t\t\n Column  6: FCO2_AVE_WEIGHTED is fCO2 mean - per cruise weighted (uatm)\t\t\t\t\t\t\t\n Column  7: FCO2_AVE_UNWTD is fCO2 mean - unweighted all obs (uatm)\t\t\t\t\t\t\t\n Column  8: FCO2_MIN_UNWTD is fCO2 min (uatm)\t\t\t\t\t\t\t\n Column  9: FCO2_MAX_UNWTD is fCO2 max (uatm)\t\t\t\t\t\t\t\n Column 10: SST_COUNT_NOBS is Number of valid sst obs (count)\t\t\t\t\t\t\t\n Column 11: SST_AVE_WEIGHTED is SST mean - per cruise weighted (degrees C)\t\t\t\t\t\t\t\n Column 12: SST_AVE_UNWTD is SST mean - unweighted all obs (degrees C)\t\t\t\t\t\t\t\n Column 13: SST_MIN_UNWTD is SST min (degrees C)\t\t\t\t\t\t\t\n Column 14: SST_MAX_UNWTD is SST max (degrees C)\t\t\t\t\t\t\t\n Column 15: SALINITY_COUNT_NOBS is Number of valid salinity obs (count)\t\t\t\t\t\t\t\n Column 16: SALINITY_AVE_WEIGHTED is Salinity mean - per cruise weighted (PSU)\t\t\t\t\t\t\t\n Column 17: SALINITY_AVE_UNWTD is Salinity mean - unweighted all obs (PSU)\t\t\t\t\t\t\t\n Column 18: SALINITY_MIN_UNWTD is Salinity min (PSU)\t\t\t\t\t\t\t\n Column 19: SALINITY_MAX_UNWTD is Salinity max (PSU)\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\nMissing values are represented as -1.E+34\t\t\t\t\t\t\t\n'

# %%
SOCAT_monthly = pd.read_csv('Data\SOCATv2022_tracks_gridded_monthly.csv', skiprows=255)
SOCAT_monthly['DATE'] = pd.to_datetime(SOCAT_monthly['DATE'] )
SOCAT_monthly
# Out:
#              DATE   LAT    LON   COUNT_NCRUISE_YEAR   FCO2_COUNT_NOBS_YEAR  \
# 0      1970-02-15   9.5  156.5                    1                      1
# 1      1970-02-15   9.5  157.5                    1                     11
# 2      1970-02-15   9.5  158.5                    1                      8
# 3      1970-02-15  10.5  155.5                    1                      1
# 4      1970-02-15  10.5  156.5                    1                      4
# ...           ...   ...    ...                  ...                    ...
# 346455 2021-12-16  63.5   20.5                    1                     88
# 346456 2021-12-16  64.5   22.5                    1                      1
# 346457 2021-12-16  64.5   23.5                    1                     79
# 346458 2021-12-16  65.5   23.5                    1                     15
# 346459 2021-12-16  65.5   24.5                    1                      4
#
#          FCO2_AVE_WEIGHTED_YEAR   FCO2_AVE_UNWTD_YEAR   FCO2_MIN_UNWTD_YEAR  \
# 0                       303.672               303.672               303.672
# 1                       311.013               311.013               306.311
# 2                       321.322               321.322               316.141
# 3                       305.066               305.066               305.066
# 4                       305.424               305.424               302.806
# ...                         ...                   ...                   ...
# 346455                  486.540               486.540               446.297
# 346456                  464.278               464.278               464.278
# 346457                  463.741               463.741               399.569
# 346458                  393.355               393.355               382.792
# 346459                  388.537               388.537               384.246
#
#          FCO2_MAX_UNWTD_YEAR   SST_COUNT_NOBS_YEAR   SST_AVE_WEIGHTED_YEAR  \
# 0                    303.672                     1               28.200000
# 1                    321.797                    11               28.409100
# 2                    326.150                     8               28.375000
# 3                    305.066                     1               27.900000
# 4                    307.795                     4               28.050000
# ...                      ...                   ...                     ...
# 346455               512.059                    88                4.125910
# 346456               464.278                     1                3.760000
# 346457               494.914                    79                3.015440
# 346458               400.042                    15                0.864667
# 346459               393.459                     4                0.135000
#
#          SST_AVE_UNWTD_YEAR   SST_MIN_UNWTD_YEAR   SST_MAX_UNWTD_YEAR  \
# 0                 28.200000                28.20                28.20
# 1                 28.409100                28.20                28.50
# 2                 28.375000                28.20                28.50
# 3                 27.900000                27.90                27.90
# 4                 28.050000                28.00                28.10
# ...                     ...                  ...                  ...
# 346455             4.125910                 2.20                 5.26
# 346456             3.760000                 3.76                 3.76
# 346457             3.015440                 1.24                 3.74
# 346458             0.864667                 0.10                 1.37
# 346459             0.135000                -0.12                 0.40
#
#          SALINITY_COUNT_NOBS_YEAR   SALINITY_AVE_WEIGHTED_YEAR  \
# 0                               0                -1.000000e+34
# 1                               0                -1.000000e+34
# 2                               0                -1.000000e+34
# 3                               0                -1.000000e+34
# 4                               0                -1.000000e+34
# ...                           ...                          ...
# 346455                         88                 5.161140e+00
# 346456                          1                 3.010000e+00
# 346457                         79                 3.019110e+00
# 346458                         15                 3.032000e+00
# 346459                          4                 2.995000e+00
#
#          SALINITY_AVE_UNWTD_YEAR   SALINITY_MIN_UNWTD_YEAR  \
# 0                  -1.000000e+34             -1.000000e+34
# 1                  -1.000000e+34             -1.000000e+34
# 2                  -1.000000e+34             -1.000000e+34
# 3                  -1.000000e+34             -1.000000e+34
# 4                  -1.000000e+34             -1.000000e+34
# ...                          ...                       ...
# 346455              5.161140e+00              3.620000e+00
# 346456              3.010000e+00              3.010000e+00
# 346457              3.019110e+00              2.990000e+00
# 346458              3.032000e+00              2.980000e+00
# 346459              2.995000e+00              2.990000e+00
#
#          SALINITY_MAX_UNWTD_YEAR
# 0                  -1.000000e+34
# 1                  -1.000000e+34
# 2                  -1.000000e+34
# 3                  -1.000000e+34
# 4                  -1.000000e+34
# ...                          ...
# 346455              5.520000e+00
# 346456              3.010000e+00
# 346457              3.090000e+00
# 346458              3.060000e+00
# 346459              3.000000e+00
#
# [346460 rows x 19 columns]

# %% [markdown]
# Lets group by year to see an overall change in CO2

# %%
SOCAT_monthly.columns
# Out:
# Index(['DATE', ' LAT', ' LON', ' COUNT_NCRUISE_YEAR', ' FCO2_COUNT_NOBS_YEAR',
#        ' FCO2_AVE_WEIGHTED_YEAR', ' FCO2_AVE_UNWTD_YEAR',
#        ' FCO2_MIN_UNWTD_YEAR', ' FCO2_MAX_UNWTD_YEAR', ' SST_COUNT_NOBS_YEAR',
#        ' SST_AVE_WEIGHTED_YEAR', ' SST_AVE_UNWTD_YEAR', ' SST_MIN_UNWTD_YEAR',
#        ' SST_MAX_UNWTD_YEAR', ' SALINITY_COUNT_NOBS_YEAR',
#        ' SALINITY_AVE_WEIGHTED_YEAR', ' SALINITY_AVE_UNWTD_YEAR',
#        ' SALINITY_MIN_UNWTD_YEAR', ' SALINITY_MAX_UNWTD_YEAR'],
#       dtype='object')

# %%
SOCAT_monthly.groupby(SOCAT_monthly.DATE.dt.year)[' FCO2_AVE_WEIGHTED_YEAR', ' FCO2_MIN_UNWTD_YEAR', ' FCO2_MAX_UNWTD_YEAR'].mean().reset_index()
# Out:
# C:\Users\Pablo\AppData\Local\Temp/ipykernel_26124/1059436680.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   SOCAT_monthly.groupby(SOCAT_monthly.DATE.dt.year)[' FCO2_AVE_WEIGHTED_YEAR', ' FCO2_MIN_UNWTD_YEAR', ' FCO2_MAX_UNWTD_YEAR'].mean().reset_index()
#     DATE   FCO2_AVE_WEIGHTED_YEAR   FCO2_MIN_UNWTD_YEAR   FCO2_MAX_UNWTD_YEAR
# 0   1970               301.145795            298.402968            304.071412
# 1   1973               294.448030            289.051939            298.944121
# 2   1974               319.841720            316.847600            323.393760
# 3   1975               312.281735            308.930029            316.022559
# 4   1976               311.088020            308.035160            314.395120
# 5   1977               300.586000            299.535800            302.238929
# 6   1978               315.590949            312.806622            318.600783
# 7   1979               345.571385            340.570992            350.783540
# 8   1980               346.896434            342.863490            351.311953
# 9   1981               296.179182            290.986234            301.415653
# 10  1982               313.181930            307.226414            319.471698
# 11  1983               328.191942            323.974528            332.947905
# 12  1984               319.796236            315.025076            324.928373
# 13  1985               324.606735            319.450531            329.727930
# 14  1986               338.369043            335.370345            341.471622
# 15  1987               333.751649            329.016521            338.621892
# 16  1988               341.982455            337.321855            347.106065
# 17  1989               341.961646            335.675151            348.250955
# 18  1990               348.309490            345.134327            351.703155
# 19  1991               338.077885            333.666914            342.490043
# 20  1992               343.539400            339.469565            347.637104
# 21  1993               336.856271            331.661610            342.141797
# 22  1994               354.563205            348.244519            361.199394
# 23  1995               344.285188            337.711581            351.150050
# 24  1996               348.616172            341.529893            356.024697
# 25  1997               339.207398            330.812315            347.996246
# 26  1998               343.978138            336.701405            351.693214
# 27  1999               356.987069            348.579250            366.074217
# 28  2000               353.478902            342.860214            364.639638
# 29  2001               356.980551            346.533074            368.681473
# 30  2002               353.716964            346.130223            361.729408
# 31  2003               355.212114            347.502886            363.595515
# 32  2004               357.729757            348.919893            367.690878
# 33  2005               358.222963            349.628555            368.270189
# 34  2006               354.366101            344.616844            364.968402
# 35  2007               352.249292            343.151798            361.832980
# 36  2008               355.994990            346.668198            366.451974
# 37  2009               350.769793            340.049551            362.692851
# 38  2010               363.107155            352.951032            374.420251
# 39  2011               356.180445            345.224270            368.763794
# 40  2012               360.528463            349.912568            373.616677
# 41  2013               365.074225            354.528380            377.111935
# 42  2014               361.964776            349.627468            376.452311
# 43  2015               369.504513            359.294858            380.431319
# 44  2016               373.602499            363.913628            384.190854
# 45  2017               371.626069            360.352153            383.773040
# 46  2018               373.665976            359.364888            389.569417
# 47  2019               378.465081            364.181828            395.064869
# 48  2020               381.063514            368.450252            395.153776
# 49  2021               380.483013            366.026859            397.468490

# %%
SOCAT_monthly.describe(include= 'all')
# Out:
# C:\Users\Pablo\AppData\Local\Temp/ipykernel_26124/4286643872.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   SOCAT_monthly.describe(include= 'all')
#                        DATE            LAT            LON  \
# count                346460  346460.000000  346460.000000
# unique                  529            NaN            NaN
# top     2017-01-16 00:00:00            NaN            NaN
# freq                   2004            NaN            NaN
# first   1970-02-15 00:00:00            NaN            NaN
# last    2021-12-16 00:00:00            NaN            NaN
# mean                    NaN      15.747356       1.911773
# std                     NaN      38.886761     114.887094
# min                     NaN     -78.500000    -179.500000
# 25%                     NaN      -7.500000     -82.500000
# 50%                     NaN      25.500000     -21.500000
# 75%                     NaN      43.500000     139.500000
# max                     NaN      89.500000     179.500000
#
#          COUNT_NCRUISE_YEAR   FCO2_COUNT_NOBS_YEAR   FCO2_AVE_WEIGHTED_YEAR  \
# count         346460.000000          346460.000000            346460.000000
# unique                  NaN                    NaN                      NaN
# top                     NaN                    NaN                      NaN
# freq                    NaN                    NaN                      NaN
# first                   NaN                    NaN                      NaN
# last                    NaN                    NaN                      NaN
# mean               1.139277              97.242374               360.511728
# std                0.489235             379.054144                48.051448
# min                1.000000               1.000000                44.496600
# 25%                1.000000              10.000000               337.685750
# 50%                1.000000              27.000000               360.954000
# 75%                1.000000              85.000000               384.731000
# max               18.000000          103371.000000              4310.250000
#
#          FCO2_AVE_UNWTD_YEAR   FCO2_MIN_UNWTD_YEAR   FCO2_MAX_UNWTD_YEAR  \
# count          346460.000000         346460.000000         346460.000000
# unique                   NaN                   NaN                   NaN
# top                      NaN                   NaN                   NaN
# freq                     NaN                   NaN                   NaN
# first                    NaN                   NaN                   NaN
# last                     NaN                   NaN                   NaN
# mean              360.517639            350.451451            371.742030
# std                48.133753             49.257382             61.005728
# min                44.496600              7.198820             45.541100
# 25%               337.677000            330.084000            344.760000
# 50%               360.955000            354.518000            367.845000
# 75%               384.731250            377.829250            392.905250
# max              4118.470000           2254.040000           7748.570000
#
#          SST_COUNT_NOBS_YEAR   SST_AVE_WEIGHTED_YEAR   SST_AVE_UNWTD_YEAR  \
# count          346460.000000            3.464600e+05         3.464600e+05
# unique                   NaN                     NaN                  NaN
# top                      NaN                     NaN                  NaN
# freq                     NaN                     NaN                  NaN
# first                    NaN                     NaN                  NaN
# last                     NaN                     NaN                  NaN
# mean               97.227296           -1.385441e+30        -1.385441e+30
# std               379.020959            1.176968e+32         1.176968e+32
# min                 0.000000           -1.000000e+34        -1.000000e+34
# 25%                10.000000            9.042250e+00         9.040240e+00
# 50%                27.000000            1.902465e+01         1.902640e+01
# 75%                85.000000            2.638603e+01         2.638505e+01
# max            103371.000000            3.265550e+01         3.265550e+01
#
#          SST_MIN_UNWTD_YEAR   SST_MAX_UNWTD_YEAR   SALINITY_COUNT_NOBS_YEAR  \
# count          3.464600e+05         3.464600e+05              346460.000000
# unique                  NaN                  NaN                        NaN
# top                     NaN                  NaN                        NaN
# freq                    NaN                  NaN                        NaN
# first                   NaN                  NaN                        NaN
# last                    NaN                  NaN                        NaN
# mean          -1.385441e+30        -1.385441e+30                  90.966721
# std            1.176968e+32         1.176968e+32                 377.459164
# min           -1.000000e+34        -1.000000e+34                   0.000000
# 25%            8.547750e+00         9.504000e+00                   6.000000
# 50%            1.850000e+01         1.956300e+01                  20.000000
# 75%            2.607000e+01         2.669100e+01                  78.000000
# max            3.238000e+01         3.496900e+01              103371.000000
#
#          SALINITY_AVE_WEIGHTED_YEAR   SALINITY_AVE_UNWTD_YEAR  \
# count                  3.464600e+05              3.464600e+05
# unique                          NaN                       NaN
# top                             NaN                       NaN
# freq                            NaN                       NaN
# first                           NaN                       NaN
# last                            NaN                       NaN
# mean                  -1.178087e+33             -1.178087e+33
# std                    3.223819e+33              3.223819e+33
# min                   -1.000000e+34             -1.000000e+34
# 25%                    3.298480e+01              3.298360e+01
# 50%                    3.436190e+01              3.436180e+01
# 75%                    3.529010e+01              3.529000e+01
# max                    4.224150e+01              4.224150e+01
#
#          SALINITY_MIN_UNWTD_YEAR   SALINITY_MAX_UNWTD_YEAR
# count               3.464600e+05              3.464600e+05
# unique                       NaN                       NaN
# top                          NaN                       NaN
# freq                         NaN                       NaN
# first                        NaN                       NaN
# last                         NaN                       NaN
# mean               -1.178087e+33             -1.178087e+33
# std                 3.223819e+33              3.223819e+33
# min                -1.000000e+34             -1.000000e+34
# 25%                 3.281000e+01              3.313075e+01
# 50%                 3.422700e+01              3.448400e+01
# 75%                 3.518200e+01              3.539000e+01
# max                 4.223700e+01              4.226300e+01

# %%
ax = sns.lineplot(x="DATE", y=" FCO2_AVE_WEIGHTED_YEAR", data=SOCAT_monthly.groupby(SOCAT_monthly.DATE.dt.year)[' FCO2_AVE_WEIGHTED_YEAR', ' FCO2_MIN_UNWTD_YEAR', ' FCO2_MAX_UNWTD_YEAR'].mean().reset_index())
# Out:
# C:\Users\Pablo\AppData\Local\Temp/ipykernel_26124/3226535953.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ax = sns.lineplot(x="DATE", y=" FCO2_AVE_WEIGHTED_YEAR", data=SOCAT_monthly.groupby(SOCAT_monthly.DATE.dt.year)[' FCO2_AVE_WEIGHTED_YEAR', ' FCO2_MIN_UNWTD_YEAR', ' FCO2_MAX_UNWTD_YEAR'].mean().reset_index())

# %% [markdown]
# # Lets throw it on a map!

# %%
import matplotlib.pyplot as plt

# %%
pip install geopandas
# Out:
# Collecting geopandasNote: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_6096dbfd9ec9477d86db5dda6ecdd2df\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_6096dbfd9ec9477d86db5dda6ecdd2df\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-ew994aq_'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_6096dbfd9ec9477d86db5dda6ecdd2df\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/67/5c/4e028e84a1f0cb3f8a994217cf2366360ca984dfc1433f6171de527d0dca/Fiona-1.8.21.tar.gz#sha256=3a0edca2a7a070db405d71187214a43d2333a57b4097544a3fcc282066a58bfc (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_a8b6e51e50774233996e41b702cde550\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_a8b6e51e50774233996e41b702cde550\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-iw4950t2'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_a8b6e51e50774233996e41b702cde550\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ec/f7/093890341a7e8fbfcdfa04caf4dfb588ebab32c13ceaa6a3819da79ea106/Fiona-1.8.20.tar.gz#sha256=a70502d2857b82f749c09cb0dea3726787747933a2a1599b5ab787d74e3c143b (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_c771dec6b504449491d02f661f165839\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_c771dec6b504449491d02f661f165839\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-jujco3te'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_c771dec6b504449491d02f661f165839\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a0/d9/6042aeb073d11341f7726de0586ff71c13117c34959dcf07bd4ee6d4b93e/Fiona-1.8.19.tar.gz#sha256=b9059e0b29c2e9e6b817e53f941e77e1aca7075f986005d38db307067b60458f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_7339c91dce6c47be95c6aaadedcb7ec2\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_7339c91dce6c47be95c6aaadedcb7ec2\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-5q_auwll'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_7339c91dce6c47be95c6aaadedcb7ec2\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9f/e8/401cdaa58d862a25c4b3365acf7d2bd7ac77191e3dc9acdcdac0eff20ff0/Fiona-1.8.18.tar.gz#sha256=b732ece0ff8886a29c439723a3e1fc382718804bb057519d537a81308854967a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_9dede13952cf46d48da00f327c2e2681\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_9dede13952cf46d48da00f327c2e2681\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-kplxcquv'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_9dede13952cf46d48da00f327c2e2681\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/88/62/69347ba2c41b526e1953c4cb66d51170b2869808863c03af202ba0121670/Fiona-1.8.17.tar.gz#sha256=716201c21246587f374785bec6d6a20a984fe1f6c2b0e83bf15127eb8f724d0c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_a9beaa97f3aa47de933426388c4df8c8\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_a9beaa97f3aa47de933426388c4df8c8\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-ryaritly'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_a9beaa97f3aa47de933426388c4df8c8\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/1e/60/dfc6115a11338d8aa96cacd8c60635223d9c97d61d556c90acc5dfd663fa/Fiona-1.8.16.tar.gz#sha256=fd6dfb65959becc916e9f6928618bfd59c16cdbc413ece0fbac61489cd11255f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_1983a54de42f432aa48fcb018067eed4\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_1983a54de42f432aa48fcb018067eed4\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-2u0l8dr4'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_1983a54de42f432aa48fcb018067eed4\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/55/2f/17450ec2c8fcc720a8a3e4d9a383499508475c7cfb90f7eca9fb585ac598/Fiona-1.8.15.tar.gz#sha256=3b1c9b5c834fae2fe947cfaea176db890bc6750d1a6ba9f54d969c19ffcd191e (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_c71d420f8751443ab179e1977cee259c\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_c71d420f8751443ab179e1977cee259c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-vux23mje'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_c71d420f8751443ab179e1977cee259c\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5c/fd/5ec54f2d9b3d5dd23dd443fad5630d6b872e2664814c68b856c47e0d65af/Fiona-1.8.14.tar.gz#sha256=6eac038206c89d2cf5f99ea38b81cc228dc21eac5f47870a9a32d453b0007f4d (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_13360d7c230e475ebf7199395d7419bb\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_13360d7c230e475ebf7199395d7419bb\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-z2_gxwfy'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_13360d7c230e475ebf7199395d7419bb\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6d/42/f4a7cac53b28fa70e9a93d0e89a24d33e14826dad6644b699362ad84dde0/Fiona-1.8.13.post1.tar.gz#sha256=1a432bf9fd56f089256c010da009c90d4a795c531a848132c965052185336600 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_a5eb70ed400843d5abde645b67e19d28\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_a5eb70ed400843d5abde645b67e19d28\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-1zpx_1oy'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_a5eb70ed400843d5abde645b67e19d28\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/be/04/31d0a6f03943b1684f32c9b861be40c1fd282468fa6bd54ddf4a774e6b0f/Fiona-1.8.13.tar.gz#sha256=5ec34898c8b983a723fb4e949dd3e0ed7e691c303e51f6bfd61e52ac9ac813ae (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_1c719bd84ca44a92bbda77938474f4bf\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_1c719bd84ca44a92bbda77938474f4bf\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-bgwip35i'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_1c719bd84ca44a92bbda77938474f4bf\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/97/d8/feab39987296437fbdc3029fb39752a14355d217d73b93471010b8dd63a3/Fiona-1.8.12.tar.gz#sha256=c9266ddf6ae2a64fcea20014ddf27f800ac07584f2fdb09c2a02f3b3a52e371c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_cf730eab0e6f4e2faa352310b35cb185\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_cf730eab0e6f4e2faa352310b35cb185\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-8xxym09g'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_cf730eab0e6f4e2faa352310b35cb185\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9d/f4/0a0ddc6174c4a93679b5f1dd3535e7ef8989828e6d5f86112de681f8c87b/Fiona-1.8.11.tar.gz#sha256=1e7ca9e051f5bffa1c43c70d573da9ca223fc076b84fa73380614fc02b9eb7f6 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_be2b8972d1914c70840cee6e0f68fc31\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_be2b8972d1914c70840cee6e0f68fc31\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-7pz3exq1'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_be2b8972d1914c70840cee6e0f68fc31\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/13/73/f80b491ed8559326fab202a6d6333a3cd6e8be1e9d782bc6c0d03d476457/Fiona-1.8.10.tar.gz#sha256=ff562eb2f3960e21f8c7f050ddd7f47a763869ea14afc2234a40df72666c6a2c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_3fdd3c99c06e4ddf89226373e0b3171f\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_3fdd3c99c06e4ddf89226373e0b3171f\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-8cd3wra8'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_3fdd3c99c06e4ddf89226373e0b3171f\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9b/52/45e75507660ce0e86176d0f59b659560f687e2c7e9ebf82a10e7dcd2d3b7/Fiona-1.8.9.post2.tar.gz#sha256=210fb038b579fab38f35ddbdd31b9725f4d5099b3edfd4b87c983e5d47b79983 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_3825c9b56488497084295d647c0c860f\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_3825c9b56488497084295d647c0c860f\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-8ile8mvn'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_3825c9b56488497084295d647c0c860f\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/0e/a4/d9dd7399be809d3990f5000fb6ae43189ea26ae88be1bed3a4c9ddc1becc/Fiona-1.8.9.post1.tar.gz#sha256=d5e0ea0b8addffe9cba4cb59e2bd495b015230e7a1b1597974f5048211930199 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_666d59f472a8412a9903b0a6736a3391\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_666d59f472a8412a9903b0a6736a3391\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-6p8zo4rs'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_666d59f472a8412a9903b0a6736a3391\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ad/92/dcbd8c54d697c22f299b5af63b6df3acfbd06c6d72e249614c05be99337c/Fiona-1.8.9.tar.gz#sha256=4dd6e2f5327c1174143c7c8594a75d373bc72f2c9a2a6daee312c3186a128add (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_e6e4e00ff2d3496a88e4cbc3e829192d\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_e6e4e00ff2d3496a88e4cbc3e829192d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-yuvvgnh_'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_e6e4e00ff2d3496a88e4cbc3e829192d\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/94/7f/e288db1ad63d759d494c30caae34f865e0c6927588c490705e91b7134193/Fiona-1.8.8.tar.gz#sha256=711c3be73203b37812992089445a1e4e9d3d6b64e667389f7b15406e15a91e83 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_27ac9995eb0a466ea877a9fa579995de\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_27ac9995eb0a466ea877a9fa579995de\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-l0vbyo_o'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_27ac9995eb0a466ea877a9fa579995de\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/78/62/daafd070aebefa639df247705b97f13f7cfad43895581b5cae41bd886709/Fiona-1.8.7.tar.gz#sha256=a55a23615bad3e142d4e4cda97bb5de83c778a80049222e9dffae93c13b5cf93 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_854d177391694acaaa42675fcd9a7611\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_854d177391694acaaa42675fcd9a7611\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-wtzbhjmj'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_854d177391694acaaa42675fcd9a7611\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/41/9d/63696e7b1de42aad294d4781199a408bec593d8fdb80a2b4a788c911a33b/Fiona-1.8.6.tar.gz#sha256=fa31dfe8855b9cd0b128b47a4df558f1b8eda90d2181bff1dd9854e5556efb3e (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_4d5cde20c88b4227855a6abd2381b87c\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_4d5cde20c88b4227855a6abd2381b87c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-font1ppb'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_4d5cde20c88b4227855a6abd2381b87c\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/7b/af/1c2c83c4a8363a4ce9fea817b1910b5e071bed012e18257faa2a0ab3cfe7/Fiona-1.8.5.tar.gz#sha256=4f5cc2d449edbbf693c83e24cdada72de7c41297383d16fcc92387eb445e9d35 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_ac76c751267a48d981ad3555b8b76bfc\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_ac76c751267a48d981ad3555b8b76bfc\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-ji0tmxy2'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_ac76c751267a48d981ad3555b8b76bfc\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3a/16/84960540e9fce61d767fd2f0f1d95f4c63e99ab5d8fddc308e8b51b059b8/Fiona-1.8.4.tar.gz#sha256=aec9ab2e3513c9503ec123b1a8573bee55fc6a66e2ac07088c3376bf6738a424 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_a520caba98674dea836d0a68c4b9e55f\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_a520caba98674dea836d0a68c4b9e55f\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-qtqa0bqq'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_a520caba98674dea836d0a68c4b9e55f\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/46/d1/fcdb32513a03abfde0d97fd9782ce0f8cc0540fa6c6ce783e87b94064964/Fiona-1.8.3.tar.gz#sha256=3e831100a23c3b6cd32b98baf0c9e2119d909b44a5cf4533d3625f61dcf2d2b1 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_966df2deded841ddba9b413867172395\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_966df2deded841ddba9b413867172395\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-iewl9o6z'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_966df2deded841ddba9b413867172395\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/25/50/0466d5d83e1859c5ca38351ee932d64cc5635f9d4dad522879e58f4b0018/Fiona-1.8.2.tar.gz#sha256=4c6419b7ac29136708029f6a44b4ccd458735a4d241016c7b1bab41685c08d8f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_e1db074c51ea4328b491b6ac8b6f9490\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_e1db074c51ea4328b491b6ac8b6f9490\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-9io52fct'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_e1db074c51ea4328b491b6ac8b6f9490\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3e/5f/0c6704efeea2ff3fba7f54cc6ec38070157f21bc1cffa7bdfa7c9f6b8f7a/Fiona-1.8.1.tar.gz#sha256=4c34bb4c5cd788aaf14e5484c3b7de407b1a8a7c7b2d29bbb2e8b37931e83b8d (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_5c30bf9fb318405698bbc6276e61c7ff\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_5c30bf9fb318405698bbc6276e61c7ff\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-9j_5pja5'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_5c30bf9fb318405698bbc6276e61c7ff\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2a/bd/c1efc2680f338e5941121c776d6323af6b9698ac739e22ba523cee348a7f/Fiona-1.8.0.tar.gz#sha256=20141a9ece06daa7bb4333fba640c2fe39a49f8aca5492d1da8595d41e91844a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\Users\Pablo\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_0b5e29d6a7a74ca4baf026a6d1d089ed\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_0b5e29d6a7a74ca4baf026a6d1d089ed\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Pablo\AppData\Local\Temp\pip-wheel-_l66fk7l'
#        cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_0b5e29d6a7a74ca4baf026a6d1d089ed\
#   Complete output (42 lines):
#   c:\Users\Pablo\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#     warnings.warn(msg)
#   c:\Users\Pablo\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#     warnings.warn(msg)
#   c:\Users\Pablo\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\fiona
#   copying .\fiona\collection.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\compat.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\crs.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\drvsupport.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\errors.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\inspector.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\rfc3339.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\tool.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\transform.py -> build\lib.win-amd64-3.8\fiona
#   copying .\fiona\__init__.py -> build\lib.win-amd64-3.8\fiona
#   creating build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\bounds.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\calc.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\cat.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\collect.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\distrib.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\dump.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\env.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\filter.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\helpers.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\info.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\insp.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\load.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\ls.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\main.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\options.py -> build\lib.win-amd64-3.8\fiona\fio
#   copying .\fiona\fio\__init__.py -> build\lib.win-amd64-3.8\fiona\fio
#   running build_ext
#   building 'fiona._transform' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for fiona
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_0b5e29d6a7a74ca4baf026a6d1d089ed\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_0b5e29d6a7a74ca4baf026a6d1d089ed\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Pablo\AppData\Local\Temp\pip-record-o8mfei79\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\Users\Pablo\anaconda3\Include\fiona'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-a96ddm0p\fiona_0b5e29d6a7a74ca4baf026a6d1d089ed\
#     Complete output (12 lines):
#     c:\Users\Pablo\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#       warnings.warn(msg)
#     c:\Users\Pablo\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#       warnings.warn(msg)
#     c:\Users\Pablo\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#       warnings.warn(msg)
#     running install
#     running build
#     running build_py
#     running build_ext
#     building 'fiona._transform' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'c:\Users\Pablo\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_0b5e29d6a7a74ca4baf026a6d1d089ed\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-a96ddm0p\\fiona_0b5e29d6a7a74ca4baf026a6d1d089ed\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Pablo\AppData\Local\Temp\pip-record-o8mfei79\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\Users\Pablo\anaconda3\Include\fiona' Check the logs for full command output.
#   Using cached geopandas-0.11.1-py3-none-any.whl (1.0 MB)
# Collecting fiona>=1.8
#   Using cached Fiona-1.8.21.tar.gz (1.0 MB)
#   Using cached Fiona-1.8.20.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.19.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.18.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.17.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.16.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.15.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.14.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.13.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.12.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.11.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.10.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.8.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.7.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.6.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.5.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.4.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.3.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.1.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.0.tar.gz (1.4 MB)
# Collecting geopandas
#   Using cached geopandas-0.11.0-py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
# Requirement already satisfied: pyproj>=2.2.0 in c:\users\pablo\anaconda3\lib\site-packages (from geopandas) (3.3.1)
# Requirement already satisfied: shapely>=1.6 in c:\users\pablo\anaconda3\lib\site-packages (from geopandas) (1.8.4)
# Requirement already satisfied: pandas>=0.25.0 in c:\users\pablo\anaconda3\lib\site-packages (from geopandas) (1.3.4)
#   Using cached geopandas-0.10.1-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.10.0-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#   Using cached geopandas-0.8.2-py2.py3-none-any.whl (962 kB)
# Collecting fiona
#   Using cached Fiona-1.7.13.tar.gz (731 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\pablo\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\pablo\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\pablo\anaconda3\lib\site-packages (from pandas>=0.25.0->geopandas) (2021.3)
# Requirement already satisfied: certifi in c:\users\pablo\anaconda3\lib\site-packages (from pyproj>=2.2.0->geopandas) (2021.10.8)
# Requirement already satisfied: six>=1.5 in c:\users\pablo\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.0->geopandas) (1.16.0)
# Requirement already satisfied: cligj>=0.4 in c:\users\pablo\anaconda3\lib\site-packages (from fiona->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\pablo\anaconda3\lib\site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: munch in c:\users\pablo\anaconda3\lib\site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: click>=4.0 in c:\users\pablo\anaconda3\lib\site-packages (from cligj>=0.4->fiona->geopandas) (8.0.3)
# Requirement already satisfied: colorama in c:\users\pablo\anaconda3\lib\site-packages (from click>=4.0->cligj>=0.4->fiona->geopandas) (0.4.4)
# Building wheels for collected packages: fiona
#   Building wheel for fiona (setup.py): started
#   Building wheel for fiona (setup.py): finished with status 'error'
#   Running setup.py clean for fiona
# Failed to build fiona
# Installing collected packages: fiona, geopandas
#     Running setup.py install for fiona: started
#     Running setup.py install for fiona: finished with status 'error'

# %%
import sys
'geopandas' in sys.modules
# Out:
# False

# %%
pip install geopandas
# Out:
# Collecting geopandasNote: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_f7f357b007b246c096ff6910fa099d71\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_f7f357b007b246c096ff6910fa099d71\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-03em2g4x'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_f7f357b007b246c096ff6910fa099d71\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/67/5c/4e028e84a1f0cb3f8a994217cf2366360ca984dfc1433f6171de527d0dca/Fiona-1.8.21.tar.gz#sha256=3a0edca2a7a070db405d71187214a43d2333a57b4097544a3fcc282066a58bfc (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_af48fe2e1fdd442fb3f56c2bfbd71105\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_af48fe2e1fdd442fb3f56c2bfbd71105\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-ezh5iuq5'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_af48fe2e1fdd442fb3f56c2bfbd71105\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ec/f7/093890341a7e8fbfcdfa04caf4dfb588ebab32c13ceaa6a3819da79ea106/Fiona-1.8.20.tar.gz#sha256=a70502d2857b82f749c09cb0dea3726787747933a2a1599b5ab787d74e3c143b (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_5589c39859114475ba93ae2b752a916f\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_5589c39859114475ba93ae2b752a916f\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-pkbsbzn9'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_5589c39859114475ba93ae2b752a916f\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a0/d9/6042aeb073d11341f7726de0586ff71c13117c34959dcf07bd4ee6d4b93e/Fiona-1.8.19.tar.gz#sha256=b9059e0b29c2e9e6b817e53f941e77e1aca7075f986005d38db307067b60458f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_490dd8904b34476ca762113aebe006a2\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_490dd8904b34476ca762113aebe006a2\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-xlj7yqwn'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_490dd8904b34476ca762113aebe006a2\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9f/e8/401cdaa58d862a25c4b3365acf7d2bd7ac77191e3dc9acdcdac0eff20ff0/Fiona-1.8.18.tar.gz#sha256=b732ece0ff8886a29c439723a3e1fc382718804bb057519d537a81308854967a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_70252ff80fd441f099db388456261d00\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_70252ff80fd441f099db388456261d00\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-yf5shd3_'
#   Using cached geopandas-0.11.1-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\pablo\anaconda3\lib\site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\users\pablo\anaconda3\lib\site-packages (from geopandas) (3.3.0)
# Requirement already satisfied: packaging in c:\users\pablo\anaconda3\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: shapely<2,>=1.7 in c:\users\pablo\anaconda3\lib\site-packages (from geopandas) (1.8.4)
# Collecting fiona>=1.8
#   Using cached Fiona-1.8.21.tar.gz (1.0 MB)
#   Using cached Fiona-1.8.20.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.19.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.18.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.17.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.16.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.15.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.14.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.13.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.12.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.11.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.10.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.8.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.7.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.6.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.5.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.4.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.3.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.1.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.0.tar.gz (1.4 MB)
# Collecting geopandas
#   Using cached geopandas-0.11.0-py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.10.1-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.10.0-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#   Using cached geopandas-0.8.2-py2.py3-none-any.whl (962 kB)
# Collecting fiona
#   Using cached Fiona-1.7.13.tar.gz (731 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\pablo\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pablo\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\pablo\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (1.21.5)
# Requirement already satisfied: certifi in c:\users\pablo\anaconda3\lib\site-packages (from pyproj>=2.6.1.post1->geopandas) (2021.10.8)
# Requirement already satisfied: six>=1.5 in c:\users\pablo\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->geopandas) (1.16.0)
# Collecting cligj>=0.4
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting munch
#   Using cached munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: click>=4.0 in c:\users\pablo\anaconda3\lib\site-packages (from cligj>=0.4->fiona->geopandas) (8.0.4)
# Requirement already satisfied: colorama in c:\users\pablo\anaconda3\lib\site-packages (from click>=4.0->cligj>=0.4->fiona->geopandas) (0.4.4)
# Building wheels for collected packages: fiona
#   Building wheel for fiona (setup.py): started
#   Building wheel for fiona (setup.py): finished with status 'error'
#   Running setup.py clean for fiona
# Failed to build fiona
# Installing collected packages: munch, cligj, click-plugins, fiona, geopandas
#     Running setup.py install for fiona: started
#     Running setup.py install for fiona: finished with status 'error'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_70252ff80fd441f099db388456261d00\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/88/62/69347ba2c41b526e1953c4cb66d51170b2869808863c03af202ba0121670/Fiona-1.8.17.tar.gz#sha256=716201c21246587f374785bec6d6a20a984fe1f6c2b0e83bf15127eb8f724d0c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_0a688996e0b946f69663cceba778a3b7\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_0a688996e0b946f69663cceba778a3b7\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-f4j760wu'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_0a688996e0b946f69663cceba778a3b7\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/1e/60/dfc6115a11338d8aa96cacd8c60635223d9c97d61d556c90acc5dfd663fa/Fiona-1.8.16.tar.gz#sha256=fd6dfb65959becc916e9f6928618bfd59c16cdbc413ece0fbac61489cd11255f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_e4a6add42faf4e2ba2c7475b42bc9e44\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_e4a6add42faf4e2ba2c7475b42bc9e44\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-ufxskd3v'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_e4a6add42faf4e2ba2c7475b42bc9e44\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/55/2f/17450ec2c8fcc720a8a3e4d9a383499508475c7cfb90f7eca9fb585ac598/Fiona-1.8.15.tar.gz#sha256=3b1c9b5c834fae2fe947cfaea176db890bc6750d1a6ba9f54d969c19ffcd191e (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_bcdc14934d7b4b17a2048197cf7287a1\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_bcdc14934d7b4b17a2048197cf7287a1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-ggof74sf'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_bcdc14934d7b4b17a2048197cf7287a1\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5c/fd/5ec54f2d9b3d5dd23dd443fad5630d6b872e2664814c68b856c47e0d65af/Fiona-1.8.14.tar.gz#sha256=6eac038206c89d2cf5f99ea38b81cc228dc21eac5f47870a9a32d453b0007f4d (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_dd4aba04016e4bd68ea3e1d07a31725c\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_dd4aba04016e4bd68ea3e1d07a31725c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-st0cbpg_'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_dd4aba04016e4bd68ea3e1d07a31725c\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6d/42/f4a7cac53b28fa70e9a93d0e89a24d33e14826dad6644b699362ad84dde0/Fiona-1.8.13.post1.tar.gz#sha256=1a432bf9fd56f089256c010da009c90d4a795c531a848132c965052185336600 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_f498f99d043145ca835b038a2a95b934\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_f498f99d043145ca835b038a2a95b934\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-o9ubgvo_'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_f498f99d043145ca835b038a2a95b934\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/be/04/31d0a6f03943b1684f32c9b861be40c1fd282468fa6bd54ddf4a774e6b0f/Fiona-1.8.13.tar.gz#sha256=5ec34898c8b983a723fb4e949dd3e0ed7e691c303e51f6bfd61e52ac9ac813ae (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_290f4dc0a9b84f34a1c66b7b36db78d4\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_290f4dc0a9b84f34a1c66b7b36db78d4\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-__n9phel'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_290f4dc0a9b84f34a1c66b7b36db78d4\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/97/d8/feab39987296437fbdc3029fb39752a14355d217d73b93471010b8dd63a3/Fiona-1.8.12.tar.gz#sha256=c9266ddf6ae2a64fcea20014ddf27f800ac07584f2fdb09c2a02f3b3a52e371c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_b07e0fe8391d4b01b6e8c4b52c95d235\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_b07e0fe8391d4b01b6e8c4b52c95d235\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-9r_ulz2y'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_b07e0fe8391d4b01b6e8c4b52c95d235\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9d/f4/0a0ddc6174c4a93679b5f1dd3535e7ef8989828e6d5f86112de681f8c87b/Fiona-1.8.11.tar.gz#sha256=1e7ca9e051f5bffa1c43c70d573da9ca223fc076b84fa73380614fc02b9eb7f6 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_2a4b3be62b334cc78ad2e80f37a3589d\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_2a4b3be62b334cc78ad2e80f37a3589d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-vusfy0d8'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_2a4b3be62b334cc78ad2e80f37a3589d\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/13/73/f80b491ed8559326fab202a6d6333a3cd6e8be1e9d782bc6c0d03d476457/Fiona-1.8.10.tar.gz#sha256=ff562eb2f3960e21f8c7f050ddd7f47a763869ea14afc2234a40df72666c6a2c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_05c0ef33b2f6450791e5fd2be84bd23b\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_05c0ef33b2f6450791e5fd2be84bd23b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-yplajlr6'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_05c0ef33b2f6450791e5fd2be84bd23b\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9b/52/45e75507660ce0e86176d0f59b659560f687e2c7e9ebf82a10e7dcd2d3b7/Fiona-1.8.9.post2.tar.gz#sha256=210fb038b579fab38f35ddbdd31b9725f4d5099b3edfd4b87c983e5d47b79983 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_288fb03282214921af1328fd0beb7930\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_288fb03282214921af1328fd0beb7930\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-zoo6kfwt'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_288fb03282214921af1328fd0beb7930\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/0e/a4/d9dd7399be809d3990f5000fb6ae43189ea26ae88be1bed3a4c9ddc1becc/Fiona-1.8.9.post1.tar.gz#sha256=d5e0ea0b8addffe9cba4cb59e2bd495b015230e7a1b1597974f5048211930199 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_0c3806b579fd4afe853520f712e346de\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_0c3806b579fd4afe853520f712e346de\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-97osyglg'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_0c3806b579fd4afe853520f712e346de\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ad/92/dcbd8c54d697c22f299b5af63b6df3acfbd06c6d72e249614c05be99337c/Fiona-1.8.9.tar.gz#sha256=4dd6e2f5327c1174143c7c8594a75d373bc72f2c9a2a6daee312c3186a128add (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_81eabcc278054f13aa9795badae9c7fc\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_81eabcc278054f13aa9795badae9c7fc\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-3ddrxwpm'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_81eabcc278054f13aa9795badae9c7fc\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/94/7f/e288db1ad63d759d494c30caae34f865e0c6927588c490705e91b7134193/Fiona-1.8.8.tar.gz#sha256=711c3be73203b37812992089445a1e4e9d3d6b64e667389f7b15406e15a91e83 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_7ed7419025674c838c7d6b61c1d4bc51\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_7ed7419025674c838c7d6b61c1d4bc51\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-vq1r8xma'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_7ed7419025674c838c7d6b61c1d4bc51\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/78/62/daafd070aebefa639df247705b97f13f7cfad43895581b5cae41bd886709/Fiona-1.8.7.tar.gz#sha256=a55a23615bad3e142d4e4cda97bb5de83c778a80049222e9dffae93c13b5cf93 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_6644b31d8ffb4b7bb5c1fd20ce7b0d08\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_6644b31d8ffb4b7bb5c1fd20ce7b0d08\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-jcbd_w_g'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_6644b31d8ffb4b7bb5c1fd20ce7b0d08\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/41/9d/63696e7b1de42aad294d4781199a408bec593d8fdb80a2b4a788c911a33b/Fiona-1.8.6.tar.gz#sha256=fa31dfe8855b9cd0b128b47a4df558f1b8eda90d2181bff1dd9854e5556efb3e (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_31dc9a83ac0041b783afcf923106ecea\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_31dc9a83ac0041b783afcf923106ecea\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-_oeeh3rd'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_31dc9a83ac0041b783afcf923106ecea\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/7b/af/1c2c83c4a8363a4ce9fea817b1910b5e071bed012e18257faa2a0ab3cfe7/Fiona-1.8.5.tar.gz#sha256=4f5cc2d449edbbf693c83e24cdada72de7c41297383d16fcc92387eb445e9d35 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_39f931b4787549dcb9e31f5f5734bc7c\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_39f931b4787549dcb9e31f5f5734bc7c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-t9b13zao'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_39f931b4787549dcb9e31f5f5734bc7c\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3a/16/84960540e9fce61d767fd2f0f1d95f4c63e99ab5d8fddc308e8b51b059b8/Fiona-1.8.4.tar.gz#sha256=aec9ab2e3513c9503ec123b1a8573bee55fc6a66e2ac07088c3376bf6738a424 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_e61ad3254cc4426ba424f261ef710291\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_e61ad3254cc4426ba424f261ef710291\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-vlxg8w6i'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_e61ad3254cc4426ba424f261ef710291\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/46/d1/fcdb32513a03abfde0d97fd9782ce0f8cc0540fa6c6ce783e87b94064964/Fiona-1.8.3.tar.gz#sha256=3e831100a23c3b6cd32b98baf0c9e2119d909b44a5cf4533d3625f61dcf2d2b1 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_a0b1f316704b47a48533d50ca1dfc21e\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_a0b1f316704b47a48533d50ca1dfc21e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-86cnk_g5'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_a0b1f316704b47a48533d50ca1dfc21e\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/25/50/0466d5d83e1859c5ca38351ee932d64cc5635f9d4dad522879e58f4b0018/Fiona-1.8.2.tar.gz#sha256=4c6419b7ac29136708029f6a44b4ccd458735a4d241016c7b1bab41685c08d8f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_5bc928c7d24446a5bc1042907c34a05a\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_5bc928c7d24446a5bc1042907c34a05a\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-_ymr49xj'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_5bc928c7d24446a5bc1042907c34a05a\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3e/5f/0c6704efeea2ff3fba7f54cc6ec38070157f21bc1cffa7bdfa7c9f6b8f7a/Fiona-1.8.1.tar.gz#sha256=4c34bb4c5cd788aaf14e5484c3b7de407b1a8a7c7b2d29bbb2e8b37931e83b8d (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_ac7f83aed5fb464493d5913f29b0f866\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_ac7f83aed5fb464493d5913f29b0f866\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-33uvxfns'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_ac7f83aed5fb464493d5913f29b0f866\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2a/bd/c1efc2680f338e5941121c776d6323af6b9698ac739e22ba523cee348a7f/Fiona-1.8.0.tar.gz#sha256=20141a9ece06daa7bb4333fba640c2fe39a49f8aca5492d1da8595d41e91844a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\Users\Pablo\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_c8e5a5a5e7494a6ebffcfc8507bbf5de\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_c8e5a5a5e7494a6ebffcfc8507bbf5de\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Pablo\AppData\Local\Temp\pip-wheel-4cgb1hv0'
#        cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_c8e5a5a5e7494a6ebffcfc8507bbf5de\
#   Complete output (42 lines):
#   c:\Users\Pablo\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'metadata_version'
#     warnings.warn(msg)
#   c:\Users\Pablo\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'requires_python'
#     warnings.warn(msg)
#   c:\Users\Pablo\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'requires_external'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\fiona
#   copying .\fiona\collection.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\compat.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\crs.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\drvsupport.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\errors.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\inspector.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\rfc3339.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\tool.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\transform.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\__init__.py -> build\lib.win-amd64-3.9\fiona
#   creating build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\bounds.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\calc.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\cat.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\collect.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\distrib.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\dump.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\env.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\filter.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\helpers.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\info.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\insp.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\load.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\ls.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\main.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\options.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\__init__.py -> build\lib.win-amd64-3.9\fiona\fio
#   running build_ext
#   building 'fiona._transform' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for fiona
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_c8e5a5a5e7494a6ebffcfc8507bbf5de\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_c8e5a5a5e7494a6ebffcfc8507bbf5de\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Pablo\AppData\Local\Temp\pip-record-4pd5nk5r\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\Users\Pablo\anaconda3\Include\fiona'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-5idff0fn\fiona_c8e5a5a5e7494a6ebffcfc8507bbf5de\
#     Complete output (14 lines):
#     c:\Users\Pablo\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'metadata_version'
#       warnings.warn(msg)
#     c:\Users\Pablo\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'requires_python'
#       warnings.warn(msg)
#     c:\Users\Pablo\anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'requires_external'
#       warnings.warn(msg)
#     running install
#     c:\Users\Pablo\anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     running build_ext
#     building 'fiona._transform' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'c:\Users\Pablo\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_c8e5a5a5e7494a6ebffcfc8507bbf5de\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-5idff0fn\\fiona_c8e5a5a5e7494a6ebffcfc8507bbf5de\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Pablo\AppData\Local\Temp\pip-record-4pd5nk5r\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\Users\Pablo\anaconda3\Include\fiona' Check the logs for full command output.

# %%
#conda install -c conda-forge geopandas
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install GDAL-3.4.3-cp311-cp311-win32.whl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Requirement 'GDAL-3.4.3-cp311-cp311-win32.whl' looks like a filename, but the file does not exist
# ERROR: GDAL-3.4.3-cp311-cp311-win32.whl is not a supported wheel on this platform.

# %%
import fiona
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Pablo\Documents\Climate DataThon 2022\Climate-DataThon-2022\Analyses\SOCAT Analysis V1.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Pablo/Documents/Climate%20DataThon%202022/Climate-DataThon-2022/Analyses/SOCAT%20Analysis%20V1.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> import fiona
#
# File c:\Users\Pablo\anaconda3\lib\site-packages\fiona\__init__.py:85, in <module>
#      82     os.environ["PATH"] = os.environ["PATH"] + ";" + libdir
#      84 import fiona._loading
# ---> 85 with fiona._loading.add_gdal_dll_directories():
#      86     from fiona.collection import BytesCollection, Collection
#      87     from fiona.drvsupport import supported_drivers
#
# AttributeError: partially initialized module 'fiona' has no attribute '_loading' (most likely due to a circular import)

# %%
#conda install -c conda-forge cython
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install fiona
# Out:
# Requirement already satisfied: fiona in c:\users\pablo\anaconda3\lib\site-packages (1.8.21)
# Requirement already satisfied: attrs>=17 in c:\users\pablo\anaconda3\lib\site-packages (from fiona) (21.4.0)
# Requirement already satisfied: certifi in c:\users\pablo\anaconda3\lib\site-packages (from fiona) (2021.10.8)
# Requirement already satisfied: click>=4.0 in c:\users\pablo\anaconda3\lib\site-packages (from fiona) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\pablo\anaconda3\lib\site-packages (from fiona) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\pablo\anaconda3\lib\site-packages (from fiona) (1.1.1)
# Requirement already satisfied: six>=1.7 in c:\users\pablo\anaconda3\lib\site-packages (from fiona) (1.16.0)
# Requirement already satisfied: munch in c:\users\pablo\anaconda3\lib\site-packages (from fiona) (2.5.0)
# Requirement already satisfied: setuptools in c:\users\pablo\anaconda3\lib\site-packages (from fiona) (61.2.0)
# Requirement already satisfied: colorama in c:\users\pablo\anaconda3\lib\site-packages (from click>=4.0->fiona) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from shapely.geometry import Point

import geopandas as gpd
#from geopandas import GeoDataFrame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Pablo\Documents\Climate DataThon 2022\Climate-DataThon-2022\Analyses\SOCAT Analysis V1.ipynb Cell 23 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Pablo/Documents/Climate%20DataThon%202022/Climate-DataThon-2022/Analyses/SOCAT%20Analysis%20V1.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/Pablo/Documents/Climate%20DataThon%202022/Climate-DataThon-2022/Analyses/SOCAT%20Analysis%20V1.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> from shapely.geometry import Point
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Pablo/Documents/Climate%20DataThon%202022/Climate-DataThon-2022/Analyses/SOCAT%20Analysis%20V1.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> import fiona
#       <a href='vscode-notebook-cell:/c%3A/Users/Pablo/Documents/Climate%20DataThon%202022/Climate-DataThon-2022/Analyses/SOCAT%20Analysis%20V1.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> import geopandas as gpd
#
# File c:\Users\Pablo\anaconda3\lib\site-packages\fiona\__init__.py:85, in <module>
#      82     os.environ["PATH"] = os.environ["PATH"] + ";" + libdir
#      84 import fiona._loading
# ---> 85 with fiona._loading.add_gdal_dll_directories():
#      86     from fiona.collection import BytesCollection, Collection
#      87     from fiona.drvsupport import supported_drivers
#
# AttributeError: partially initialized module 'fiona' has no attribute '_loading' (most likely due to a circular import)

# %%
pip install fiona==1.8.4
# Out:
# Collecting fiona==1.8.4
#   Using cached Fiona-1.8.4.tar.gz (1.1 MB)
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\Pablo\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-1nuuhaii\\fiona_b4cc81cc525b4d778dea452eea3c0b87\\setup.py'"'"'; __file__='"'"'C:\\Users\\Pablo\\AppData\\Local\\Temp\\pip-install-1nuuhaii\\fiona_b4cc81cc525b4d778dea452eea3c0b87\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Pablo\AppData\Local\Temp\pip-pip-egg-info-wbdqzrut'
#          cwd: C:\Users\Pablo\AppData\Local\Temp\pip-install-1nuuhaii\fiona_b4cc81cc525b4d778dea452eea3c0b87\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3a/16/84960540e9fce61d767fd2f0f1d95f4c63e99ab5d8fddc308e8b51b059b8/Fiona-1.8.4.tar.gz#sha256=aec9ab2e3513c9503ec123b1a8573bee55fc6a66e2ac07088c3376bf6738a424 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement fiona==1.8.4 (from versions: 0.5, 0.6, 0.6.1, 0.6.2, 0.7, 0.8, 0.9, 0.9.1, 0.10, 0.12, 0.12.1, 0.13, 0.14, 0.15, 0.16, 0.16.1, 1.0, 1.0.1, 1.0.2, 1.0.3, 1.1, 1.1.1, 1.1.2, 1.1.3, 1.1.4, 1.1.5, 1.1.6, 1.2.0, 1.3.0, 1.4.0, 1.4.1, 1.4.2, 1.4.3, 1.4.4, 1.4.5, 1.4.6, 1.4.7, 1.4.8, 1.5.0, 1.5.1, 1.6.0, 1.6.1, 1.6.2, 1.6.3, 1.6.3.post1, 1.6.4, 1.7b1, 1.7.0, 1.7.0.post2, 1.7.1, 1.7.1.post1, 1.7.2, 1.7.3, 1.7.4, 1.7.5, 1.7.6, 1.7.7, 1.7.8, 1.7.9, 1.7.9.post1, 1.7.10, 1.7.10.post1, 1.7.11, 1.7.11.post1, 1.7.11.post2, 1.7.12, 1.7.13, 1.8a1, 1.8a2, 1.8a3, 1.8b1, 1.8b2, 1.8rc1, 1.8.0, 1.8.1, 1.8.2, 1.8.3, 1.8.4, 1.8.5, 1.8.6, 1.8.7, 1.8.8, 1.8.9, 1.8.9.post1, 1.8.9.post2, 1.8.10, 1.8.11, 1.8.12, 1.8.13, 1.8.13.post1, 1.8.14, 1.8.15, 1.8.16, 1.8.17, 1.8.18, 1.8.19, 1.8.20, 1.8.21, 1.9a1, 1.9a2)
# ERROR: No matching distribution found for fiona==1.8.4

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# bitarray                      2.4.1
# bkcharts                      0.2
# black                         19.10b0
# bleach                        4.1.0
# bokeh                         2.4.2
# boto3                         1.21.32
# botocore                      1.24.32
# Bottleneck                    1.3.4
# brotlipy                      0.7.0
# cachetools                    4.2.2
# certifi                       2021.10.8
# cffi                          1.15.0
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# click-plugins                 1.1.1
# cligj                         0.7.2
# cloudpickle                   2.0.0
# clyent                        1.2.2
# colorama                      0.4.4
# colorcet                      2.0.6
# comtypes                      1.1.10
# conda                         22.9.0
# conda-build                   3.22.0
# conda-content-trust           0+unknown
# conda-pack                    0.6.0
# conda-package-handling        1.8.1
# conda-repo-cli                1.0.4
# conda-token                   0.3.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# cookiecutter                  1.7.3
# cryptography                  3.4.8
# cssselect                     1.1.0
# cycler                        0.11.0
# Cython                        0.29.28
# cytoolz                       0.11.0
# daal4py                       2021.5.0
# dask                          2022.2.1
# datashader                    0.13.0
# datashape                     0.5.4
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# distributed                   2022.2.1
# docutils                      0.17.1
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastjsonschema                2.15.1
# filelock                      3.6.0
# Fiona                         1.8.21
# flake8                        3.9.2
# Flask                         1.1.2
# fonttools                     4.25.0
# frozenlist                    1.2.0
# fsspec                        2022.2.0
# future                        0.18.2
# GDAL                          3.4.1
# gensim                        4.1.2
# geopandas                     0.9.0
# glob2                         0.7
# google-api-core               1.25.1
# google-auth                   1.33.0
# google-cloud-core             1.7.1
# google-cloud-storage          1.31.0
# google-crc32c                 1.1.2
# google-resumable-media        1.3.1
# googleapis-common-protos      1.53.0
# greenlet                      1.1.1
# grpcio                        1.42.0
# h5py                          3.6.0
# HeapDict                      1.0.1
# holoviews                     1.14.8
# hvplot                        0.7.3
# hyperlink                     21.0.0
# idna                          3.3
# imagecodecs                   2021.8.26
# imageio                       2.9.0
# imagesize                     1.3.0
# importlib-metadata            4.11.3
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.5
# intervaltree                  3.1.0
# ipykernel                     6.9.1
# ipython                       8.2.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jdcal                         1.4.1
# jedi                          0.18.1
# Jinja2                        2.11.3
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.1.0
# json5                         0.9.6
# jsonschema                    4.4.0
# jupyter                       1.0.0
# jupyter-client                6.1.12
# jupyter-console               6.4.0
# jupyter-core                  4.9.2
# jupyter-server                1.13.5
# jupyterlab                    3.3.2
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# keyring                       23.4.0
# kiwisolver                    1.3.2
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# llvmlite                      0.38.0
# locket                        0.2.1
# lxml                          4.8.0
# mapclassify                   2.4.3
# Markdown                      3.3.4
# MarkupSafe                    2.0.1
# matplotlib                    3.5.1
# matplotlib-inline             0.1.2
# mccabe                        0.6.1
# menuinst                      1.4.18
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# mock                          4.0.3
# mpmath                        1.2.1
# msgpack                       1.0.2
# multidict                     5.1.0
# multipledispatch              0.6.0
# munch                         2.5.0
# munkres                       1.1.4
# mypy-extensions               0.4.3
# navigator-updater             0.2.1
# nbclassic                     0.3.5
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.3.0
# nest-asyncio                  1.5.5
# networkx                      2.7.1
# nltk                          3.7
# nose                          1.3.7
# notebook                      6.4.8
# numba                         0.55.1
# numexpr                       2.8.1
# numpy                         1.21.5
# numpydoc                      1.2
# olefile                       0.46
# openpyxl                      3.0.9
# packaging                     21.3
# pandas                        1.4.2
# pandocfilters                 1.5.0
# panel                         0.13.0
# param                         1.12.0
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.2.0
# pathspec                      0.7.0
# patsy                         0.5.2
# pep8                          1.7.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.0.1
# pip                           21.2.4
# pkginfo                       1.8.2
# plotly                        5.6.0
# pluggy                        1.0.0
# poyo                          0.5.0
# prometheus-client             0.13.1
# prompt-toolkit                3.0.20
# Protego                       0.1.16
# protobuf                      3.19.1
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.7.0
# pycosat                       0.6.3
# pycparser                     2.21
# pyct                          0.4.6
# pycurl                        7.44.1
# PyDispatcher                  2.0.5
# pydocstyle                    6.1.1
# pyerfa                        2.0.0
# pyflakes                      2.3.1
# Pygments                      2.11.2
# PyHamcrest                    2.0.2
# PyJWT                         2.1.0
# pylint                        2.9.6
# pyls-spyder                   0.4.0
# PyNaCl                        1.4.0
# pyodbc                        4.0.32
# pyOpenSSL                     21.0.0
# pyparsing                     3.0.4
# pyproj                        2.6.1.post1
# pyreadline                    2.1
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytest                        7.1.1
# python-dateutil               2.8.2
# python-lsp-black              1.0.0
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.2.4
# python-slugify                5.0.2
# python-snappy                 0.6.0
# pytz                          2021.3
# pyviz-comms                   2.0.2
# PyWavelets                    1.3.0
# pywin32                       302
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.2
# PyYAML                        6.0
# pyzmq                         22.3.0
# QDarkStyle                    3.0.2
# qstylizer                     0.1.10
# QtAwesome                     1.0.3
# qtconsole                     5.3.0
# QtPy                          2.0.1
# queuelib                      1.5.0
# regex                         2022.3.15
# requests                      2.27.1
# requests-file                 1.5.1
# rope                          0.22.0
# rsa                           4.7.2
# Rtree                         0.9.7
# ruamel-yaml-conda             0.15.100
# s3transfer                    0.5.0
# scikit-image                  0.19.2
# scikit-learn                  1.0.2
# scikit-learn-intelex          2021.20220215.102710
# scipy                         1.7.3
# Scrapy                        2.6.1
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# service-identity              18.1.0
# setuptools                    61.2.0
# Shapely                       1.8.4
# sip                           4.19.13
# six                           1.16.0
# smart-open                    5.1.0
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.1
# Sphinx                        4.4.0
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.1.5
# spyder-kernels                2.1.3
# SQLAlchemy                    1.4.32
# stack-data                    0.2.0
# statsmodels                   0.13.2
# sympy                         1.10.1
# tables                        3.6.1
# tabulate                      0.8.9
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.0.1
# terminado                     0.13.1
# testpath                      0.5.0
# text-unidecode                1.3
# textdistance                  4.2.1
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tifffile                      2021.7.2
# tinycss                       0.4
# tldextract                    3.2.0
# toml                          0.10.2
# tomli                         1.2.2
# toolz                         0.11.2
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# Twisted                       22.2.0
# twisted-iocpsupport           1.0.2
# typed-ast                     1.4.3
# typing_extensions             4.1.1
# ujson                         5.1.0
# Unidecode                     1.2.0
# urllib3                       1.26.9
# w3lib                         1.21.0
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.0.3
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# win-inet-pton                 1.1.0
# win-unicode-console           0.5
# wincertstore                  0.2
# wrapt                         1.12.1
# xarray                        0.20.1
# xlrd                          2.0.1
# XlsxWriter                    3.0.3
# xlwings                       0.24.9
# yapf                          0.31.0
# yarl                          1.6.3
# zict                          2.0.0
# zipp                          3.7.0
# zope.interface                5.4.0
# Note: you may need to restart the kernel to use updated packages.
